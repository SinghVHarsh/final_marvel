# %%
import hashlib
import requests
import datetime


import pandas as pd

timestamp = datetime.datetime.now().strftime('%Y-%m-%d%H:%M:%S')
pub_key = input('enter the public key')
priv_key = input('enter the private key')


name=input()
def hash_params():


    """ Marvel API requires server side API calls to include
    md5 hash of timestamp + public key + private key """

    hash_md5 = hashlib.md5()
    hash_md5.update(f'{timestamp}{priv_key}{pub_key}'.encode('utf-8'))
    hashed_params = hash_md5.hexdigest()

    return hashed_params
df_new=pd.DataFrame()
for i in range(0,4):

    params = {'ts': timestamp, 'apikey': pub_key, 'hash': hash_params(),'nameStartsWith':name,'limit':100,'offset': 100*i}
    res = requests.get('https://gateway.marvel.com:443/v1/public/characters',params=params)


    call = res.json()
    data=(call['data']['results'])
    df1=pd.json_normalize(data)
    df_new=df_new.append(df1,ignore_index=True)
df_new[['name','events.available','series.returned','stories.available','comics.available','id']]
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_16000\3605087461.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new=df_new.append(df1)
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_16000\3605087461.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new=df_new.append(df1)
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_16000\3605087461.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new=df_new.append(df1)
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_16000\3605087461.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new=df_new.append(df1)
# ...

# %%
ids=[]
names=[]
for item in results:
    ids=ids.append(item['id'])
    names=names.append(item['name'])
print(id)
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 2 in <cell line: 3>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=0'>1</a> ids=[]
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=1'>2</a> names=[]
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=2'>3</a> for item in results:
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=3'>4</a>     ids=ids.append(item['id'])
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=4'>5</a>     names=names.append(item['name'])
#
# NameError: name 'results' is not defined
